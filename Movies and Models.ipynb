# %% [markdown]
# # Movies and Models
# ### Predicting Movie Genre and Popularity

# %% [markdown]
# #### Import Dataset and Clean

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from keras.callbacks import Callback
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers import LSTM
from keras.layers.convolutional import Conv1D, MaxPooling1D
from keras.layers import Embedding, BatchNormalization
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import np_utils
from keras.utils import to_categorical

# %%
#import dataset
data = pd.read_csv("./the-movies-dataset/movies_metadata.csv")
# Out:
# /anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#extract columns that we need: genres, imdb_id, popularity, overview, vote_average, vote_count, original title
dataset = data[['original_title', 'imdb_id', 'overview', 'popularity', 'genres', 'vote_average', 'vote_count']]

# %%
#dataset overview
print(dataset.shape)
dataset
# Out:
# (45466, 7)
#                           original_title    imdb_id  \
# 0                              Toy Story  tt0114709
# 1                                Jumanji  tt0113497
# 2                       Grumpier Old Men  tt0113228
# 3                      Waiting to Exhale  tt0114885
# 4            Father of the Bride Part II  tt0113041
# 5                                   Heat  tt0113277
# 6                                Sabrina  tt0114319
# 7                           Tom and Huck  tt0112302
# 8                           Sudden Death  tt0114576
# 9                              GoldenEye  tt0113189
# 10                The American President  tt0112346
# 11           Dracula: Dead and Loving It  tt0112896
# 12                                 Balto  tt0112453
# 13                                 Nixon  tt0113987
# 14                      Cutthroat Island  tt0112760
# 15                                Casino  tt0112641
# 16                 Sense and Sensibility  tt0114388
# 17                            Four Rooms  tt0113101
# 18        Ace Ventura: When Nature Calls  tt0112281
# 19                           Money Train  tt0113845
# 20                            Get Shorty  tt0113161
# 21                               Copycat  tt0112722
# 22                             Assassins  tt0112401
# 23                                Powder  tt0114168
# 24                     Leaving Las Vegas  tt0113627
# 25                               Othello  tt0114057
# 26                          Now and Then  tt0114011
# 27                            Persuasion  tt0114117
# 28            La Cité des Enfants Perdus  tt0112682
# 29                             摇啊摇，摇到外婆桥  tt0115012
# ...                                  ...        ...
# 45436                    The Final Storm  tt1331329
# 45437                     In a Heartbeat  tt6969946
# 45438             Bloed, Zweet en Tranen  tt3814486
# 45439                       Jungle Woman  tt0036975
# 45440                  To Be Fat Like Me  tt0889600
# 45441                        Cadet Kelly  tt0294425
# 45442               Le tripot clandestin  tt0135690
# 45443    L'Homme à la tête de caoutchouc  tt0000359
# 45444                Les cartes vivantes  tt0135179
# 45445           Les affiches en goguette  tt0135122
# 45446            Le locataire diabolique  tt0127948
# 45447               Le Roi du maquillage  tt0135631
# 45448  Les Transmutations imperceptibles  tt0224286
# 45449   Pooh's Heffalump Halloween Movie  tt0457437
# 45450                  L'Homme orchestre  tt0135453
# 45451     Nouvelles luttes extravagantes  tt0135571
# 45452                        Deep Hearts  tt3054038
# 45453                                Maa  tt5690142
# 45454                  The Morning After  tt4130180
# 45455         San Michele aveva un gallo  tt0069215
# 45456                   House of Horrors  tt0038621
# 45457          Shadow of the Blair Witch  tt0265736
# 45458                The Burkittsville 7  tt0252966
# 45459                    Caged Heat 3000  tt0112613
# 45460                         Robin Hood  tt0102797
# 45461                            رگ خواب  tt6209470
# 45462                Siglo ng Pagluluwal  tt2028550
# 45463                           Betrayal  tt0303758
# 45464                Satana likuyushchiy  tt0008536
# 45465                           Queerama  tt6980792
#
#                                                 overview popularity  \
# 0      Led by Woody, Andy's toys live happily in his ...    21.9469
# 1      When siblings Judy and Peter discover an encha...    17.0155
# 2      A family wedding reignites the ancient feud be...    11.7129
# 3      Cheated on, mistreated and stepped on, the wom...    3.85949
# 4      Just when George Banks has recovered from his ...    8.38752
# 5      Obsessive master thief, Neil McCauley leads a ...    17.9249
# 6      An ugly duckling having undergone a remarkable...    6.67728
# 7      A mischievous young boy, Tom Sawyer, witnesses...    2.56116
# 8      International action superstar Jean Claude Van...    5.23158
# 9      James Bond must unmask the mysterious head of ...     14.686
# 10     Widowed U.S. president Andrew Shepherd, one of...    6.31844
# 11     When a lawyer shows up at the vampire's doorst...    5.43033
# 12     An outcast half-wolf risks his life to prevent...    12.1407
# 13     An all-star cast powers this epic look at Amer...      5.092
# 14     Morgan Adams and her slave, William Shaw, are ...    7.28448
# 15     The life of the gambling paradise – Las Vegas ...    10.1374
# 16     Rich Mr. Dashwood dies, leaving his second wif...    10.6732
# 17     It's Ted the Bellhop's first night on the job....    9.02659
# 18     Summoned from an ashram in Tibet, Ace finds hi...    8.20545
# 19     A vengeful New York transit cop decides to ste...    7.33791
# 20     Chili Palmer is a Miami mobster who gets sent ...    12.6696
# 21     An agoraphobic psychologist and a female detec...    10.7018
# 22     Assassin Robert Rath arrives at a funeral to k...    11.0659
# 23     Harassed by classmates who won't accept his sh...    12.1331
# 24     Ben Sanderson, an alcoholic Hollywood screenwr...     10.332
# 25     The evil Iago pretends to be friend of Othello...     1.8459
# 26     Waxing nostalgic about the bittersweet passage...    8.68132
# 27     This film adaptation of Jane Austen's last nov...    2.22843
# 28     A scientist in a surrealist society kidnaps ch...    9.82242
# 29     A provincial boy related to a Shanghai crime f...    1.10091
# ...                                                  ...        ...
# 45436  A stranger named Silas flees from a devastatin...   1.270832
# 45437  A closeted boy runs the risk of being outed by...   20.82178
# 45438  Bloed, Zweet en Tranen (Blood, Sweat and Tears...   0.590087
# 45439  Paula the ape woman (Acquanetta) is alive and ...   0.143223
# 45440  Pretty, popular, and slim high-schooler Aly Sc...   0.767762
# 45441  Hyperactive teenager Kelly is enrolled into a ...   4.392389
# 45442  A combination gambling den and bawdy house is ...    0.21926
# 45443  A chemist in his laboratory places upon a tabl...   1.618458
# 45444  A bearded magician holds up a large playing ca...   0.208349
# 45445  A wall full of advertising posters comes to life.   0.148131
# 45446  A man rents an apartment and furnishes it in r...   0.725084
# 45447  The background of this picture represents a sc...   0.213973
# 45448  This shows a prince entering upon the stage of...   0.071782
# 45449  It's Halloween in the 100 Acre Wood, and Roo's...   2.568495
# 45450  A band-leader has arranged seven chairs for th...   1.109068
# 45451         A series of fantastical wrestling matches.   0.225432
# 45452  Deep Hearts is a film about the Bororo Fulani,...   0.011025
# 45453  The bliss of a biology teacher’s family life i...   1.559596
# 45454  The Morning After is a feature film that consi...   0.139936
# 45455  Sentenced to life imprisonment for illegal act...   0.225051
# 45456  An unsuccessful sculptor saves a madman named ...   0.222814
# 45457  In this true-crime documentary, we delve into ...   0.076061
# 45458  A film archivist revisits the story of Rustin ...    0.38645
# 45459  It's the year 3000 AD. The world's most danger...   0.661558
# 45460  Yet another version of the classic epic, with ...   5.683753
# 45461        Rising and falling between a man and woman.   0.072051
# 45462  An artist struggles to finish his work while a...   0.178241
# 45463  When one of her hits goes wrong, a professiona...   0.903007
# 45464  In a small town live two brothers, one a minis...   0.003503
# 45465  50 years after decriminalisation of homosexual...   0.163015
#
#                                                   genres  vote_average  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...           7.7
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...           6.9
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...           6.5
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           6.1
# 4                         [{'id': 35, 'name': 'Comedy'}]           5.7
# 5      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...           7.7
# 6      [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...           6.2
# 7      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           5.4
# 8      [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           5.5
# 9      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...           6.6
# 10     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           6.5
# 11     [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...           5.7
# 12     [{'id': 10751, 'name': 'Family'}, {'id': 16, '...           7.1
# 13     [{'id': 36, 'name': 'History'}, {'id': 18, 'na...           7.1
# 14     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           5.7
# 15     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           7.8
# 16     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...           7.2
# 17     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...           6.5
# 18     [{'id': 80, 'name': 'Crime'}, {'id': 35, 'name...           6.1
# 19     [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...           5.4
# 20     [{'id': 35, 'name': 'Comedy'}, {'id': 53, 'nam...           6.4
# 21     [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...           6.5
# 22     [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...           6.0
# 23     [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...           6.3
# 24     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...           7.1
# 25                         [{'id': 18, 'name': 'Drama'}]           7.0
# 26     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           6.6
# 27     [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...           7.4
# 28     [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...           7.6
# 29     [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...           6.5
# ...                                                  ...           ...
# 45436  [{'id': 28, 'name': 'Action'}, {'id': 9648, 'n...           3.7
# 45437  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...           8.3
# 45438                      [{'id': 18, 'name': 'Drama'}]           6.8
# 45439  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...           5.8
# 45440  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...           5.0
# 45441                     [{'id': 35, 'name': 'Comedy'}]           5.2
# 45442                                                 []           5.0
# 45443  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...           7.6
# 45444                    [{'id': 14, 'name': 'Fantasy'}]           6.1
# 45445  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...           4.5
# 45446  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...           6.7
# 45447                                                 []           6.0
# 45448                                                 []           5.0
# 45449  [{'id': 16, 'name': 'Animation'}, {'id': 10751...           5.4
# 45450  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...           6.5
# 45451  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...           6.5
# 45452                [{'id': 99, 'name': 'Documentary'}]           0.0
# 45453  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...           6.6
# 45454  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...           4.0
# 45455                                                 []           6.0
# 45456  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...           6.3
# 45457  [{'id': 9648, 'name': 'Mystery'}, {'id': 27, '...           7.0
# 45458                     [{'id': 27, 'name': 'Horror'}]           7.0
# 45459           [{'id': 878, 'name': 'Science Fiction'}]           3.5
# 45460  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...           5.7
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...           4.0
# 45462                      [{'id': 18, 'name': 'Drama'}]           9.0
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...           3.8
# 45464                                                 []           0.0
# 45465                                                 []           0.0
#
#        vote_count
# 0          5415.0
# 1          2413.0
# 2            92.0
# 3            34.0
# 4           173.0
# 5          1886.0
# 6           141.0
# 7            45.0
# 8           174.0
# 9          1194.0
# 10          199.0
# 11          210.0
# 12          423.0
# 13           72.0
# 14          137.0
# 15         1343.0
# 16          364.0
# 17          539.0
# 18         1128.0
# 19          224.0
# 20          305.0
# 21          199.0
# 22          394.0
# 23          143.0
# 24          365.0
# 25           33.0
# 26           91.0
# 27           36.0
# 28          308.0
# 29           17.0
# ...           ...
# 45436        11.0
# 45437       146.0
# 45438        11.0
# 45439         2.0
# 45440        12.0
# 45441       145.0
# 45442         3.0
# 45443        29.0
# 45444         8.0
# 45445         2.0
# 45446        12.0
# 45447         6.0
# 45448         2.0
# 45449         7.0
# 45450        22.0
# 45451         6.0
# 45452         0.0
# 45453        14.0
# 45454         2.0
# 45455         3.0
# 45456         8.0
# 45457         2.0
# 45458         1.0
# 45459         1.0
# 45460        26.0
# 45461         1.0
# 45462         3.0
# 45463         6.0
# 45464         0.0
# 45465         0.0
#
# [45466 rows x 7 columns]

# %%
#clean up dataset bad values
dataset = dataset[dataset['popularity'] != 0.0]
dataset = dataset[dataset['genres'] != '[]']
dataset = dataset.dropna()

# %%
#create series for each column we're interested in
overviews = dataset['overview']
popularities = dataset['popularity']
genres = dataset['genres']

# %%
#callback function to get accuracy, precision, recall and f1score - taken and adapted from: https://github.com/keras-team/keras/issues/5794
class Metrics(Callback):

    def on_train_begin(self, logs={}):
     self.val_f1s = []
     self.val_recalls = []
     self.val_precisions = []

    def on_epoch_end(self, epoch, logs={}):
     val_predict = (np.asarray(self.model.predict(self.validation_data[0]))).round()
     val_targ = self.validation_data[1]
     _val_f1 = f1_score(val_targ, val_predict, average='weighted')
     _val_recall = recall_score(val_targ, val_predict, average='weighted')
     _val_precision = precision_score(val_targ, val_predict, average='weighted')
     self.val_f1s.append(_val_f1)
     self.val_recalls.append(_val_recall)
     self.val_precisions.append(_val_precision)
     print("val_f1: " + str(_val_f1) + " val_precision: " + str(_val_precision) + " val_recall " + str(_val_recall))
     return
 
metrics = Metrics()

# %%
#function to pick random genre
def find_genre(x):
    lst = []
    for elt in x.split():
        if elt[1:-3].istitle():
            lst.append(elt[1:-3])
    if not lst:
        return 'Drama'
    return lst[0]

# %%
#select random genre for each datapoint
genres = genres.apply(lambda x: find_genre(x))
print(set(genres))
# Out:
# {'Action', 'Thriller', 'War', 'Horror', 'Western', 'Documentary', 'History', 'Crime', 'Animation', 'Adventure', 'Fantasy', 'Music', 'Drama', 'Scie', 'Comedy', 'Foreign', 'Family', 'Mystery', 'Romance'}

# %% [markdown]
# #### Using Models to Predict Genre Based on Overview

# %%
#split dataset into training and testing data
X_train, X_test, y_train, y_test = train_test_split(overviews, genres, test_size=0.4, random_state=0)

# %%
#create Tokenizer of at most 10000 words and train on all overviews
max_idx = 10000
t = Tokenizer(num_words=max_idx)

t.fit_on_texts(overviews)

# %%
#transform overviews to integer sequences using tokenizer
X_train = t.texts_to_sequences(X_train)
X_test = t.texts_to_sequences(X_test)

# %%
# Turn all training examples to length of 600 using padding
max_len = 600

X_train = sequence.pad_sequences(X_train, max_len)
X_test = sequence.pad_sequences(X_test, max_len)

print("new x_train shape is: ", X_train.shape)
print("new x_test shape is: ", X_test.shape)
# Out:
# new x_train shape is:  (25377, 600)
# new x_test shape is:  (16918, 600)

# %%
#one-hot vectorize genre labels
lb = preprocessing.LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.transform(y_test)

# %%
# Create Recurrent Model for genres
model = Sequential()

# Add embedding to words
model.add(Embedding(input_dim=max_idx+1, output_dim=64,
                    input_length=max_len))

# Add 1D Convolutional layer
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(Dropout(.15))
model.add(MaxPooling1D(pool_size=2))

# Add LSTM layer
model.add((LSTM(16, return_sequences=False, recurrent_dropout=.15)))
model.add(Dropout(.15))

# Add dense layer
model.add(Dense(32))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(.2))

# Add final softmax layer
model.add(Dense(19))
model.add(Activation('softmax'))

# Compile model using categorical crossentropy
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#fit model to data
model.fit(X_train, y_train, batch_size=512,
          epochs=7, verbose=1, validation_data=(X_test, y_test), callbacks=[metrics])
# Out:
# Train on 25377 samples, validate on 16918 samples
# Epoch 1/7
# 25377/25377 [==============================] - 43s 2ms/step - loss: 2.7786 - acc: 0.1526 - val_loss: 2.5554 - val_acc: 0.2348
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# val_f1: 0.0 val_precision: 0.0 val_recall 0.0
# Epoch 2/7
# 25377/25377 [==============================] - 40s 2ms/step - loss: 2.3377 - acc: 0.3057 - val_loss: 2.2774 - val_acc: 0.2981
# val_f1: 0.11925088245903313 val_precision: 0.3277275701073897 val_recall 0.08665326870788509
# Epoch 3/7
# 25377/25377 [==============================] - 48s 2ms/step - loss: 1.9944 - acc: 0.4133 - val_loss: 2.1466 - val_acc: 0.3565
# val_f1: 0.17431635525700165 val_precision: 0.379013692544012 val_recall 0.11792174015841116
# Epoch 4/7
# 25377/25377 [==============================] - 44s 2ms/step - loss: 1.7802 - acc: 0.4757 - val_loss: 2.1034 - val_acc: 0.3792
# val_f1: 0.20488739674634285 val_precision: 0.37800789320520706 val_recall 0.144875280766048
# Epoch 5/7
# 25377/25377 [==============================] - 45s 2ms/step - loss: 1.6231 - acc: 0.5212 - val_loss: 2.1289 - val_acc: 0.3759
# val_f1: 0.23110508899045115 val_precision: 0.39400610459110197 val_recall 0.1746069275328053
# Epoch 6/7
# 25377/25377 [==============================] - 44s 2ms/step - loss: 1.4805 - acc: 0.5601 - val_loss: 2.1786 - val_acc: 0.3791
# val_f1: 0.2629134619468008 val_precision: 0.3608069129267453 val_recall 0.22674074949757655
# Epoch 7/7
# 25377/25377 [==============================] - 45s 2ms/step - loss: 1.3380 - acc: 0.6005 - val_loss: 2.2983 - val_acc: 0.3811
# val_f1: 0.2827304459481845 val_precision: 0.36108002432307107 val_recall 0.2695945147180518

# %%
# Create Feed-Forward Model for genre
model = Sequential()

# Create first dense layer
model.add(Dense(512, input_shape=(600,)))
model.add(Activation('relu'))

# Create second dense layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Create third dense layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Create final sigmoid layer
model.add(Dense(19))
model.add(Activation('softmax'))

# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#fit model to data
model.fit(X_train, y_train, batch_size=512,
          epochs=20, verbose=1, validation_data=(X_test, y_test), callbacks=[metrics])
# Out:
# Train on 25377 samples, validate on 16918 samples
# Epoch 1/20
# 25377/25377 [==============================] - 3s 103us/step - loss: 2.6830 - acc: 0.1989 - val_loss: 2.4583 - val_acc: 0.2316
# val_f1: 0.01058679239925467 val_precision: 0.09844624400000836 val_recall 0.007152145643693108
# Epoch 2/20
#  2560/25377 [==>...........................] - ETA: 1s - loss: 2.2854 - acc: 0.2895
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# 25377/25377 [==============================] - 2s 64us/step - loss: 2.3159 - acc: 0.2733 - val_loss: 2.3636 - val_acc: 0.2741
# val_f1: 0.012069994552770176 val_precision: 0.18824214557592162 val_recall 0.006501950585175552
# Epoch 3/20
# 25377/25377 [==============================] - 2s 62us/step - loss: 2.2319 - acc: 0.2906 - val_loss: 2.3622 - val_acc: 0.2797
# val_f1: 0.013757428829395527 val_precision: 0.15923273470696866 val_recall 0.007388580210426764
# Epoch 4/20
# 25377/25377 [==============================] - 2s 62us/step - loss: 2.1679 - acc: 0.3084 - val_loss: 2.3722 - val_acc: 0.2555
# val_f1: 0.004974300907856484 val_precision: 0.14954684660079037 val_recall 0.002541671592386807
# Epoch 5/20
# 25377/25377 [==============================] - 2s 63us/step - loss: 2.1006 - acc: 0.3260 - val_loss: 2.3893 - val_acc: 0.2484
# val_f1: 0.012466199366624901 val_precision: 0.18627395878864872 val_recall 0.006501950585175552
# Epoch 6/20
# 25377/25377 [==============================] - 2s 62us/step - loss: 2.0280 - acc: 0.3490 - val_loss: 2.4176 - val_acc: 0.2495
# val_f1: 0.028358398162374465 val_precision: 0.18135099026543042 val_recall 0.015900224612838396
# Epoch 7/20
# 25377/25377 [==============================] - 2s 62us/step - loss: 1.9608 - acc: 0.3694 - val_loss: 2.4609 - val_acc: 0.2653
# val_f1: 0.0531807071722588 val_precision: 0.18713726329656818 val_recall 0.03605627142688261
# Epoch 8/20
# 25377/25377 [==============================] - 2s 63us/step - loss: 1.8805 - acc: 0.3965 - val_loss: 2.4912 - val_acc: 0.2398
# val_f1: 0.0445765896096374 val_precision: 0.2199921045340259 val_recall 0.026066910982385626
# Epoch 9/20
# 25377/25377 [==============================] - 2s 63us/step - loss: 1.8111 - acc: 0.4126 - val_loss: 2.5249 - val_acc: 0.2361
# val_f1: 0.043723281900070826 val_precision: 0.17071372859032496 val_recall 0.025889585057335383
# Epoch 10/20
# 25377/25377 [==============================] - 2s 63us/step - loss: 1.7359 - acc: 0.4357 - val_loss: 2.6204 - val_acc: 0.2264
# val_f1: 0.062067679285002286 val_precision: 0.1693481828395766 val_recall 0.04031209362808843
# Epoch 11/20
# 25377/25377 [==============================] - 2s 65us/step - loss: 1.6481 - acc: 0.4633 - val_loss: 2.6609 - val_acc: 0.2168
# val_f1: 0.05682149816813186 val_precision: 0.16426754519508452 val_recall 0.03487409859321433
# Epoch 12/20
# 25377/25377 [==============================] - 2s 63us/step - loss: 1.5853 - acc: 0.4849 - val_loss: 2.7601 - val_acc: 0.2337
# val_f1: 0.0770342382172714 val_precision: 0.15581276344387465 val_recall 0.053670646648540016
# Epoch 13/20
# 25377/25377 [==============================] - 2s 64us/step - loss: 1.5172 - acc: 0.5067 - val_loss: 2.8539 - val_acc: 0.2355
# val_f1: 0.09350826427959401 val_precision: 0.16663973342623312 val_recall 0.07122591322851402
# Epoch 14/20
# 25377/25377 [==============================] - 2s 64us/step - loss: 1.4585 - acc: 0.5251 - val_loss: 2.9101 - val_acc: 0.2280
# val_f1: 0.09105499447749968 val_precision: 0.163780032375813 val_recall 0.06637900461047405
# Epoch 15/20
# 25377/25377 [==============================] - 2s 64us/step - loss: 1.3927 - acc: 0.5447 - val_loss: 2.9745 - val_acc: 0.2234
# val_f1: 0.09614947950129919 val_precision: 0.17439002021215233 val_recall 0.06974819718642866
# Epoch 16/20
# 25377/25377 [==============================] - 2s 64us/step - loss: 1.3350 - acc: 0.5632 - val_loss: 3.0554 - val_acc: 0.2196
# val_f1: 0.09147677121562106 val_precision: 0.1590956203725371 val_recall 0.06655633053552429
# Epoch 17/20
# 25377/25377 [==============================] - 2s 67us/step - loss: 1.2836 - acc: 0.5804 - val_loss: 3.1931 - val_acc: 0.2215
# val_f1: 0.10996339764267327 val_precision: 0.17003332891499454 val_recall 0.08434803168223194
# Epoch 18/20
# 25377/25377 [==============================] - 2s 64us/step - loss: 1.2273 - acc: 0.5953 - val_loss: 3.2468 - val_acc: 0.2172
# val_f1: 0.10396902666406145 val_precision: 0.16158234442724353 val_recall 0.07932379713914174
# Epoch 19/20
# 25377/25377 [==============================] - 2s 65us/step - loss: 1.1828 - acc: 0.6081 - val_loss: 3.4428 - val_acc: 0.2242
# val_f1: 0.1274820169706697 val_precision: 0.16501597252778352 val_recall 0.10881900933916538
# Epoch 20/20
# 25377/25377 [==============================] - 2s 67us/step - loss: 1.1415 - acc: 0.6211 - val_loss: 3.4108 - val_acc: 0.2131
# val_f1: 0.1127140081997765 val_precision: 0.16405018982977596 val_recall 0.08931315758363872

# %%
#create logistic regression classifier
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression(multi_class='multinomial', solver='lbfgs')

# %%
#fit classifier on training data
y_train = np.argmax(y_train, axis=1)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#test and evaluate classifier on test data
y_test = np.argmax(y_test, axis=1)

print("Accuracy Score: " + str(accuracy_score(y_test, clf.predict(X_test))))
print("Precision: " + str(precision_score(y_test, clf.predict(X_test), average='weighted')))
print("Recall: " + str(recall_score(y_test, clf.predict(X_test), average='weighted')))
print("F1 Score: " + str(f1_score(y_test, clf.predict(X_test), average='weighted')))
# Out:
# Accuracy Score: 0.2688852110178508
# Precision: 0.1471210261457681
# Recall: 0.2688852110178508
# F1 Score: 0.15291740359424152

# %%
#create naive bayes classifier
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

# %%
#fit classifier on training data
nb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
#test and evaluate classifier on test data
print("Accuracy Score: " + str(accuracy_score(y_test, nb.predict(X_test))))
print("Precision: " + str(precision_score(y_test, nb.predict(X_test), average='weighted')))
print("Recall: " + str(recall_score(y_test, nb.predict(X_test), average='weighted')))
print("F1 Score: " + str(f1_score(y_test, nb.predict(X_test), average='weighted')))
# Out:
# Accuracy Score: 0.0074476888521101785
# Precision: 0.17048801066935934
# Recall: 0.0074476888521101785
# F1 Score: 0.00730608205646312

# %% [markdown]
# #### Using Models to Predict Popularity Based on Overview

# %%
#split data into training and testing sets (60-40)
X_train, X_test, y_train2, y_test2 = train_test_split(overviews, popularities, test_size=0.4, random_state=0)

# %%
#create Tokenizer of at most 10000 words and train on all overviews
max_idx = 10000
t = Tokenizer(num_words=max_idx)

t.fit_on_texts(overviews)

# %%
#transform overviews to integer sequences using tokenizer
X_train = t.texts_to_sequences(X_train)
X_test = t.texts_to_sequences(X_test)

# %%
# Turn all training examples to length of 600 using padding
max_len = 600

X_train = sequence.pad_sequences(X_train, max_len)
X_test = sequence.pad_sequences(X_test, max_len)

print("new x_train shape is: ", X_train.shape)
print("new x_test shape is: ", X_test.shape)
# Out:
# new x_train shape is:  (25377, 600)
# new x_test shape is:  (16918, 600)

# %%
#clean and adapt popularity scores
y_train2 = y_train2.astype(np.float)
y_test2 = y_test2.astype(np.float)
y_train2 = y_train2.apply(lambda x: np.log(x+1))
y_test2 = y_test2.apply(lambda x: np.log(x+1))

# %%
#scale popularity scores to 0-100 range
scaler = MinMaxScaler(feature_range=(0,100))
scaler.fit(y_train2.values.reshape(-1, 1))

y_train2 = scaler.transform(y_train2.values.reshape(-1, 1))
y_test2 = scaler.transform(y_test2.values.reshape(-1, 1))

# %%
# Create recurrent model for popularity
model = Sequential()

# Add embedding to words
model.add(Embedding(input_dim=max_idx+1, output_dim=64,
                    input_length=max_len))

# Add 1D Convolutional layer
model.add(Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'))
model.add(Dropout(.15))
model.add(MaxPooling1D(pool_size=2))

# Add LSTM layer
model.add((LSTM(16, return_sequences=False, recurrent_dropout=.15)))
model.add(Dropout(.15))

# Add dense layer
model.add(Dense(32))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(.2))

# Add final dense layer layer
model.add(Dense(1))
model.add(Activation('linear'))

# Compile model with mse
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['mae'])

# %%
#fit model to data
model.fit(X_train, y_train2, batch_size=512,
          epochs=7, verbose=1, validation_data=(X_test, y_test2))
# Out:
# Train on 25377 samples, validate on 16918 samples
# Epoch 1/7
# 25377/25377 [==============================] - 45s 2ms/step - loss: 227.2576 - mean_absolute_error: 12.1820 - val_loss: 223.8226 - val_mean_absolute_error: 13.1479
# Epoch 2/7
# 25377/25377 [==============================] - 44s 2ms/step - loss: 200.1289 - mean_absolute_error: 11.6883 - val_loss: 203.0502 - val_mean_absolute_error: 12.2232
# Epoch 3/7
# 25377/25377 [==============================] - 47s 2ms/step - loss: 192.6843 - mean_absolute_error: 11.4573 - val_loss: 195.0756 - val_mean_absolute_error: 11.5435
# Epoch 4/7
# 25377/25377 [==============================] - 42s 2ms/step - loss: 186.7657 - mean_absolute_error: 11.2397 - val_loss: 207.7572 - val_mean_absolute_error: 11.2710
# Epoch 5/7
# 25377/25377 [==============================] - 46s 2ms/step - loss: 178.8114 - mean_absolute_error: 10.9292 - val_loss: 202.7555 - val_mean_absolute_error: 12.2864
# Epoch 6/7
# 25377/25377 [==============================] - 45s 2ms/step - loss: 171.8792 - mean_absolute_error: 10.6959 - val_loss: 226.0732 - val_mean_absolute_error: 12.9373
# Epoch 7/7
# 25377/25377 [==============================] - 43s 2ms/step - loss: 164.4005 - mean_absolute_error: 10.4008 - val_loss: 209.4789 - val_mean_absolute_error: 12.1328

# %%
# Create feed-forward model for popularity
model = Sequential()

# Create first dense layer
model.add(Dense(512, input_shape=(600,)))
model.add(Activation('relu'))

# Create second dense layer
model.add(Dense(512))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Create third dense layer
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.2))

# Create final sigmoid layer
model.add(Dense(1))
model.add(Activation('linear'))

# Compile model
model.compile(loss='mean_squared_error', optimizer='sgd', metrics=['mae'])

# %%
#fit model to data
model.fit(X_train, y_train2, batch_size=512,
          epochs=20, verbose=1, validation_data=(X_test, y_test2))
# Out:
# Train on 25377 samples, validate on 16918 samples
# Epoch 1/20
# 25377/25377 [==============================] - 3s 99us/step - loss: 210.4568 - mean_absolute_error: 11.9323 - val_loss: 219.9984 - val_mean_absolute_error: 11.6564
# Epoch 2/20
# 25377/25377 [==============================] - 1s 56us/step - loss: 192.6082 - mean_absolute_error: 11.5146 - val_loss: 208.0701 - val_mean_absolute_error: 11.7776
# Epoch 3/20
# 25377/25377 [==============================] - 1s 56us/step - loss: 186.3981 - mean_absolute_error: 11.3229 - val_loss: 212.4008 - val_mean_absolute_error: 11.6936
# Epoch 4/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 181.6914 - mean_absolute_error: 11.1620 - val_loss: 214.5459 - val_mean_absolute_error: 11.8787
# Epoch 5/20
# 25377/25377 [==============================] - 2s 60us/step - loss: 176.2937 - mean_absolute_error: 10.9638 - val_loss: 225.3897 - val_mean_absolute_error: 11.7578
# Epoch 6/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 170.6819 - mean_absolute_error: 10.7657 - val_loss: 220.5572 - val_mean_absolute_error: 11.8281
# Epoch 7/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 163.9592 - mean_absolute_error: 10.4888 - val_loss: 228.3696 - val_mean_absolute_error: 11.8611
# Epoch 8/20
# 25377/25377 [==============================] - 1s 57us/step - loss: 157.1867 - mean_absolute_error: 10.2203 - val_loss: 232.7615 - val_mean_absolute_error: 12.0369
# Epoch 9/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 150.8229 - mean_absolute_error: 9.9724 - val_loss: 232.3516 - val_mean_absolute_error: 12.3726
# Epoch 10/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 144.7692 - mean_absolute_error: 9.7069 - val_loss: 237.7147 - val_mean_absolute_error: 12.4339
# Epoch 11/20
# 25377/25377 [==============================] - 1s 57us/step - loss: 137.0951 - mean_absolute_error: 9.3941 - val_loss: 237.0881 - val_mean_absolute_error: 12.5331
# Epoch 12/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 129.3921 - mean_absolute_error: 9.0662 - val_loss: 239.5938 - val_mean_absolute_error: 12.1881
# Epoch 13/20
# 25377/25377 [==============================] - 2s 60us/step - loss: 123.4000 - mean_absolute_error: 8.7743 - val_loss: 241.3564 - val_mean_absolute_error: 12.4533
# Epoch 14/20
# 25377/25377 [==============================] - 2s 62us/step - loss: 117.5523 - mean_absolute_error: 8.5255 - val_loss: 246.0437 - val_mean_absolute_error: 12.5265
# Epoch 15/20
# 25377/25377 [==============================] - 2s 60us/step - loss: 110.4054 - mean_absolute_error: 8.2231 - val_loss: 249.8333 - val_mean_absolute_error: 12.7686
# Epoch 16/20
# 25377/25377 [==============================] - 2s 60us/step - loss: 105.3836 - mean_absolute_error: 8.0024 - val_loss: 256.5804 - val_mean_absolute_error: 12.8503
# Epoch 17/20
# 25377/25377 [==============================] - 1s 58us/step - loss: 99.7639 - mean_absolute_error: 7.7278 - val_loss: 267.8413 - val_mean_absolute_error: 12.6603
# Epoch 18/20
# 25377/25377 [==============================] - 2s 60us/step - loss: 95.4056 - mean_absolute_error: 7.5326 - val_loss: 252.8558 - val_mean_absolute_error: 12.6336
# Epoch 19/20
# 25377/25377 [==============================] - 2s 63us/step - loss: 90.6642 - mean_absolute_error: 7.3009 - val_loss: 272.2538 - val_mean_absolute_error: 13.4356
# Epoch 20/20
# 25377/25377 [==============================] - 2s 61us/step - loss: 86.9604 - mean_absolute_error: 7.1187 - val_loss: 252.4020 - val_mean_absolute_error: 12.8308
